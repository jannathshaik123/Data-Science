# %% [markdown]
# # **Data Visualization**
#
# #### *Aim:*
# 1. To understand the importance of data visualization in the field of analytics and knowledge mining
# 2. Make use of python libraries to extract personal user information
# 3. Covering basics important graphs in the field of regression, classification, KDE etc, and how to understand the correlation.
# 4. Covering fundamental basics and some advanced concepts of matplotlib, and it's object oriented nature of use
# 5. Covering fundamental basics of seaborn library and use of style and color to concisely extract information with good visual depictions
# 6. Understanding the basic usage of pandas data structures and it's extended use of graph plotting
#
# ## Matplotlib Overall Lecture
#
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python. So if you happen to be familiar with matlab, matplotlib will feel natural to you.
#
# It is an excellent 2D and 3D graphics library for generating scientific figures.
#
# Some of the major Pros of Matplotlib are:
#
# * Generally easy to get started for simple plots
# * Support for custom labels and texts
# * Great control of every element in a figure
# * High-quality output in many formats
# * Very customizable in general
#
# #### How to install the library into your environment:
#
# * Open command prompt under the virtual environment you intend to use or if it is google collab then simply add the below command into the code cell and run it
#
# -> pip install matplotlib
#
# or
#
# ->     `conda install matplotlib`
#
# #### How to import:
#
# * Type and run the below command in your python script or your notebook code cell
# * We import the library name `matplotlib.pyplot` with object name `plt` for easier use and access

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# You'll also need to use this line to see plots in the notebook:

# %%
# %matplotlib inline

# %% [markdown]
# Tha above line is *only* for jupyter notebooks, if you are using another editor, you'll use: **plt.show()** at the end of all your plotting commands to have the figure pop up in another window.

# %% [markdown]
# #### Starting with Basics:

# %%
import numpy as np
x = np.linspace(0, 5, 11)
y = x ** 2

# %% [markdown]
# You can also pass lists in the above code, but here we are making use of data structures like numpy and pandas that does the same work as arrays and data frames (like the ones you will find in excel sheets).
#
# The above code allows x to obtain a numpy array that contains 10 elements of floating point value which are distrubted evenly between the integers 0 and 5.

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %% [markdown]
# Let's plot a simple graph to show the relationship between x and y from the above code!

# %%
plt.plot(x, y, 'b')  # where r is for the color red
plt.xlabel('x')
plt.ylabel('y')
plt.title("x = y^2")
plt.show()

# %% [markdown]
# **Creating subplots**
#
# `plt.subplot(nrows,ncols,plot_number)`

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r')
plt.subplot(1,2,2)
plt.plot(y,x,'g--')
plt.show()

# %% [markdown]
# #### Matplot Object Oriented API Method
#
# The main idea in using the more formal Object Oriented method is to create figure objects and then just call methods or attributes off of that object. This approach is nicer when dealing with a canvas that has multiple plots on it.
#
# To begin we create a figure instance. Then we can add axes to that figure:

# %%
# Step 1: Create an empty canvas 
fig = plt.figure()
#Step 2: Set the axes for your figure 
axis = fig.add_axes([0.3,0.3,0.4,0.7]) # params: Left,Bottom,Width,Height(range:0 to 1)
#Step 3: plot the graph
axis.plot(x,y,'r')
axis.set_xlabel('x')
axis.set_ylabel('y')
axis.set_title('x=y^2')
# Out:
# Text(0.5, 1.0, 'x=y^2')

# %% [markdown]
# Code is a little more complicated, but the advantage is that we now have full control of where the plot axes are placed, and we can easily add more than one axis to the figure:

# %%
# Creating multiple subplots
fig = plt.figure()
#Step 2: Set the axes for your figures
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis2 = fig.add_axes([0.2,0.46,0.4,0.3])
#Step 3: plot the graphs
axis1.plot(x,y,'r')
axis1.set_xlabel('x')
axis1.set_ylabel('y')
axis1.set_title('x=y^2')

axis2.plot(y,x,'g--')
axis2.set_xlabel('y')
axis2.set_ylabel('x')
axis2.set_title('y = log2(x)')
# Out:
# Text(0.5, 1.0, 'y = log2(x)')

# %% [markdown]
# **Use of subplots()**
#
# Good for automatically creating multiple graphs through iteration

# %%
fig, axis = plt.subplots(nrows=1, ncols=2)
axis
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002C02B3CE190>,
# ...
#       dtype=object)

# %%
for ax in axis:
    ax.plot(x, y, 'b')
    ax.set_title('graph')

# Display the graph objects
fig

# %% [markdown]
# *Note:* If no nrows and ncols are mentioned then the default value is taken to be 1,1
#
# A common issue with matplolib is overlapping subplots or figures. We ca use **fig.tight_layout()** or **plt.tight_layout()** method, which automatically adjusts the positions of the axes on the figure canvas so that there is no overlapping content:

# %%
fig, axs = plt.subplots(2,3)
fig.tight_layout()

# %%
fig, axis = plt.subplots(nrows=1,ncols=2)
for ax in axis:
    ax.plot(x, y, 'b')
    ax.set_title('graph')

# Display the graph objects
fig
plt.tight_layout()

# %% [markdown]
# ### Figure size, aspect ratio and DPI
#
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the `figsize` and `dpi` keyword arguments.
# * `figsize` is a tuple of the width and height of the figure in inches
# * `dpi` is the dots-per-inch (pixel per inch).
#
# For example:

# %%
fig = plt.figure(figsize=(8,4), dpi=100)

# %%
fig, axis = plt.subplots(figsize=(12,3))
axis.plot(x,y,'b')
axis.set_xlabel('x')
axis.set_ylabel('y')
axis.set_title('graph2')
# Out:
# Text(0.5, 1.0, 'graph2')

# %% [markdown]
# #### Save Figure
#
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.Here we can also optionally specify the DPI and choose between different output formats:
#
# To save a figure to a file we can use the `savefig` method in the `Figure` class:

# %%
fig.savefig('picture_one.png', dpi = 200)

# %% [markdown]
# #### Labels, Linestyles, Linewidth and Axis Ticks
#
# With matplotlib, we can define the colors of lines and other graphical elements in a number of ways. First of all, we can use the MATLAB-like syntax where `'b'` means blue, `'g'` means green, etc. The MATLAB API for selecting line styles are also supported: where, for example, 'b.-' means a blue line with dots.
#
# You can use the **label="label text"** keyword argument when plots or other objects are added to the figure, and then using the **legend** method without arguments to add the legend to the figure.
#
# The **legend** function takes an optional keyword argument **loc** that can be used to specify where in the figure the legend is to be drawn. The allowed values of **loc** are numerical codes for the various places the legend can be drawn.
#
# See the [documentation page](http://matplotlib.org/users/legend_guide.html#legend-location) for details.

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, 'b.-', label='x^2') # blue line with dots
ax.plot(x, x**3, 'g--', label = 'x^3') # green dashed line
ax.plot(x, x+80, color="#8B008B", label='x+80', linewidth=0.25)        # RGB hex code
ax.plot(x, x+30, color="#FF8C00", label ='x+30', linewidth=2.0)        # RGB hex code 

# loc value can be 1: Upper right corner, 2: Upper left corner, 3: lower left corner, 4: Lower right corner
# Most common to choose
ax.legend(loc=0) # let matplotlib decide the optimal location

# %% [markdown]
# #### Plot Range
#
# We can configure the ranges of the axes using the `set_ylim` and `set_xlim` methods in the axis object, or `axis('tight')` for automatically getting "tightly fitted" axes ranges:

# %%
fig, axis = plt.subplots(1,3,figsize=(12,4))

axis[0].plot(x,x**2,'b')
axis[0].set_title('Default axis set')

axis[1].plot(x,x**3,'r')
axis[1].axis('tight')
axis[1].set_title('Under tight fit axes')

axis[2].plot(x,x**2,'g')
axis[2].set_xlim([2,5])
axis[2].set_ylim([0,60])
axis[2].set_title('Under custom axes')
# Out:
# Text(0.5, 1.0, 'Under custom axes')

# %% [markdown]
# We can explicitly determine where we want the axis ticks with `set_xticks` and `set_yticks`, which both take a list of values for where on the axis the ticks are to be placed.

# %%
fig, ax = plt.subplots(figsize=(12,3))
ax.plot(x,x**2,x,x**3, x,x**4) # To plot more than one graph line on a canvas
ax.set_xticks([0,1,2,3,4])
ax.set_yticks([0,50,100,150])

# %% [markdown]
# #### Other Plot Types

# %%
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(0,1000),100)
plt.hist(data)
# Out:
# (array([ 6., 10., 11.,  7., 10., 10.,  9.,  8., 15., 14.]),
#  array([ 17. , 114.9, 212.8, 310.7, 408.6, 506.5, 604.4, 702.3, 800.2,
#         898.1, 996. ]),
#  <a list of 10 Patch objects>)

# %%
data = [np.random.normal(0,std,100) for std in range(1,4)]
plt.boxplot(data,vert=True, patch_artist=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2c02b27a700>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2c02b27ac40>,
# ...
#  'boxes': [<matplotlib.patches.PathPatch at 0x2c02b27a4f0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x2c02b268f10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x2c02b268fa0>,
# ...
#  'means': []}

# %% [markdown]
# #### Further Reading
#
# * http://www.matplotlib.org - The project web page for matplotlib.
# * https://github.com/matplotlib/matplotlib - The source code for matplotlib.
# * http://matplotlib.org/gallery.html - A large gallery showcaseing various types of plots matplotlib can create. Highly recommended!
# * http://www.loria.fr/~rougier/teaching/matplotlib - A good matplotlib tutorial.
# * http://scipy-lectures.github.io/matplotlib/matplotlib.html - Another good matplotlib reference.

# %% [markdown]
# ## Seaborn Visualization Basics
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# 1. Helps you explore and understand your data.
# 2. It's plotting functions operate on dataframes and arrays containing whole datasets.
# 3. It internally performs the necessary semantic mapping and statistical aggregation to produce informative plots.
# 4. It's dataset-oriented, declarative API lets you focus on what the different elements of your plots mean, rather than on the details of how to draw them.
# 5. They come with pre-made dataset to impleemnt test runs
#
# *Note:* The core difference between the use of Seaborn and Matplotlib is the last point. Seaborn is far more statistically oriented
#
# #### To install the library:
#
# `pip install seaborn`
#
# #### To import seaborn into your notebook

# %%
import seaborn as sns

# %%
# Applying the theme
sns.set(style="white", palette='Spectral')

# %% [markdown]
# *Note:* Can use either `sns.set` or `sns.set_theme` depending on the version you are using. For further details on paramters open [documentation](https://seaborn.pydata.org/generated/seaborn.set_theme.html)
#
# #### Obtaining Data

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %% [markdown]
# #### Plotting Distribution Graphs
# Some plots under this:
# * distplot
# * jointplot
# * pairplot
# * rugplot
# * kdeplot
#
# #### Distplot
# The distplot shows the distribution of a univariate set of observations.

# %%
sns.distplot(tips.total_bill, bins = 30)

# %% [markdown]
# *Note:* To remove the kde line, use `kde = False` as a paramter sns.distplot()

# %% [markdown]
# #### jointplot
#
# jointplot() allows you to basically match up two distplots for bivariate data. With your choice of what **kind** parameter to compare with:
# * “scatter”
# * “reg”
# * “resid”
# * “kde”
# * “hex”

# %%
sns.jointplot(tips.total_bill,tips.tip,kind='scatter')

# %%
sns.jointplot(tips.total_bill, tips.tip, kind='hex')

# %% [markdown]
# #### Pairplot
#
# Pairplot will plot pairwise relationships across an entire dataframe (for the numerical columns) and supports a color hue argument (for categorical columns).

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='sex',palette='husl')

# %% [markdown]
# #### Kdeplots and Rugplots
#
# Kdeplots are [Kernel Density Estimation plots](http://en.wikipedia.org/wiki/Kernel_density_estimation#Practical_estimation_of_the_bandwidth). These KDE plots replace every single observation with a Gaussian (Normal) distribution centered around that value.
#
# Rugplots are actually a very simple concept, they just draw a dash mark for every point on a univariate distribution.

# %%
sns.kdeplot(tips.tip)
sns.rugplot(tips.tip)

# %% [markdown]
# #### Categorical Data
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:
#
# * boxplot
# * violinplot
# * barplot
# * countplot
#
# #### barplot and countplot
#
# These very similar plots allow you to get aggregate data off a categorical feature in your data. **barplot** is a general plot that allows you to aggregate the categorical data based off some function, by default the mean.
#
# Countplots are essentially the same as barplot except the estimator is explicitly counting the number of occurrences. Which is why we only pass the x value:

# %%
sns.barplot(tips.sex, tips.total_bill)

# %%
sns.countplot(tips.smoker)

# %% [markdown]
# *Note:* You can also change the estimator object to your own function, that converts a vector to a scaler
#
# Eg: By using `estimator=np.std` as parameter under barplot

# %% [markdown]
# ## boxplot and violinplot
#
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.
#
# A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution.

# %%
sns.boxplot(tips.day,tips.total_bill,palette='rainbow')

# %%
sns.boxplot(x="day", y="total_bill", hue="smoker",data=tips, palette="coolwarm")

# %%
sns.violinplot(tips.day,tips.total_bill,palette='rainbow')

# %% [markdown]
# #### Regression Plots
#
# **lmplot** allows you to display linear models, but it also conveniently allows you to split up those plots based off of features, as well as coloring the hue based off of features.

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')

# %% [markdown]
# ### Pandas Built-in Data Visualization
#
# It's built-off of matplotlib, but it's baked into pandas for easier usage!  There are several plot types built-in to pandas, most of them statistical plots by nature:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# You can also just call df.plot(kind='hist') or replace that kind argument with any of the key terms shown in the list above (e.g. 'box','barh', etc..)
# * [Documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.ht)
